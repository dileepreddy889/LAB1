# %%
a = {'hello': 1, 'ram': 2, 'there': 3}
b = {'who': 6, 'he': 4, 'at': 5}
b.update(a)
# a and b are two dict
# concatinating two dict

# %%
for key, value in sorted(b.items(), key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# hello: 1
# ram: 2
# there: 3
# he: 4
# at: 5
# who: 6
